# %% [markdown]
# # Day 4: Classification

# %%
#predicting Quantitative data -if the answer is YES or NO

# %%
import pandas as pd
pd.set_option('display.max_columns',100)

# %%
df=pd.read_csv('hr_data.csv')

# %% [markdown]
# ### Explarotary Data Analysis(EDA)

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df['Attrition'].value_counts()
# Out:
# No     1020
# Yes     185
# Name: Attrition, dtype: int64

# %%
df.Attrition
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465    NaN
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
d={'Yes':1,'No':0}
df['Attrition']=df['Attrition'].map(d)

# %%
df['Attrition']
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    NaN
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1470, dtype: float64

# %%
filled=df[df['Attrition'].notnull()]

# %%
empty=df[df['Attrition'].isnull()]

# %%
filled.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
empty.head()
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 367   50  Travel_Rarely       1046  Research & Development                10
# 368   40  Travel_Rarely        575                   Sales                22
# 369   31  Travel_Rarely        408  Research & Development                 9
# 370   21  Travel_Rarely        156                   Sales                12
# 371   29  Travel_Rarely       1283  Research & Development                23
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  \
# 367          3  Technical Degree              1             491
# 368          2         Marketing              1             492
# 369          4     Life Sciences              1             493
# 370          3     Life Sciences              1             494
# 371          3     Life Sciences              1             495
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
filled.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
x=filled.drop('Attrition',axis=1)
x.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
y=filled['Attrition']
y.head()
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: Attrition, dtype: float64

# %%
x=pd.get_dummies(x,drop_first=True)
x.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# ...

# %%
x.shape
# Out:
# (1205, 46)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

# %%
g=GaussianNB()
b=BernoulliNB()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
g.fit(x,y)
# Out:
# GaussianNB()

# %%
b.fit(x,y)
# Out:
# BernoulliNB()

# %%
predg=g.predict(x)

# %%
predb=b.predict(x)

# %%
accuracy_score(y,predg)
# Out:
# 0.808298755186722

# %%
accuracy_score(y,predb)
# Out:
# 0.8448132780082988

# %%
accuracy_score(y,predk)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.83      0.88      1020
#          1.0       0.42      0.68      0.52       185
#
#     accuracy                           0.81      1205
#    macro avg       0.68      0.76      0.70      1205
# weighted avg       0.86      0.81      0.83      1205

# %%
print(classification_report(y,predb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.94      0.91      1020
#          1.0       0.49      0.30      0.37       185
#
#     accuracy                           0.84      1205
#    macro avg       0.69      0.62      0.64      1205
# weighted avg       0.82      0.84      0.83      1205

# %%
confusion_matrix(y,predg)
# Out:
# array([[848, 172],
#        [ 59, 126]], dtype=int64)

# %%
confusion_matrix(y,predb)
# Out:
# array([[962,  58],
#        [129,  56]], dtype=int64)

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y,predb), annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
predk=knn.predict(x)
# Out:
# C:\Users\gilbe\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
accuracy_score(y,predk)
# Out:
# 0.8556016597510373

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier()

# %%
d.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
predd=d.predict(x)

# %%
accuracy_score(y,predd)
# Out:
# 1.0

# %%
print(classification_report(y,predd))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1020
#          1.0       1.00      1.00      1.00       185
#
#     accuracy                           1.00      1205
#    macro avg       1.00      1.00      1.00      1205
# weighted avg       1.00      1.00      1.00      1205

# %%
sns.heatmap(confusion_matrix(y,predd), annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
r=RandomForestClassifier()
r.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
predr=r.predict(x)

# %%
accuracy_score(y,predr)
# Out:
# 1.0

# %%
print(classification_report(y,predr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1020
#          1.0       1.00      1.00      1.00       185
#
#     accuracy                           1.00      1205
#    macro avg       1.00      1.00      1.00      1205
# weighted avg       1.00      1.00      1.00      1205

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gr=GradientBoostingClassifier()
gr.fit(x,y)
# Out:
# GradientBoostingClassifier()

# %%
predgr=gr.predict(x)

# %%
accuracy_score(y,predgr)
# Out:
# 0.9609958506224067

# %%
x=empty.drop('Attrition',axis=1)

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
pred=r.predict(x)

# %%
empty['Attrition']=pred
# Out:
# C:\Users\gilbe\AppData\Local\Temp\ipykernel_17096\3990556093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty['Attrition']=pred

# %%
empty.head()
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 367   50  Travel_Rarely       1046  Research & Development                10
# 368   40  Travel_Rarely        575                   Sales                22
# 369   31  Travel_Rarely        408  Research & Development                 9
# 370   21  Travel_Rarely        156                   Sales                12
# 371   29  Travel_Rarely       1283  Research & Development                23
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  \
# 367          3  Technical Degree              1             491
# 368          2         Marketing              1             492
# 369          4     Life Sciences              1             493
# 370          3     Life Sciences              1             494
# 371          3     Life Sciences              1             495
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
d={0.0:'No',1.0:'Yes'}

# %%
empty['Attrition']=empty['Attrition'].map(d)
# Out:
# C:\Users\gilbe\AppData\Local\Temp\ipykernel_17096\3325167629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty['Attrition']=empty['Attrition'].map(d)

# %%
empty.head()
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 367   50  Travel_Rarely       1046  Research & Development                10
# 368   40  Travel_Rarely        575                   Sales                22
# 369   31  Travel_Rarely        408  Research & Development                 9
# 370   21  Travel_Rarely        156                   Sales                12
# 371   29  Travel_Rarely       1283  Research & Development                23
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  \
# 367          3  Technical Degree              1             491
# 368          2         Marketing              1             492
# 369          4     Life Sciences              1             493
# 370          3     Life Sciences              1             494
# 371          3     Life Sciences              1             495
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#filling missing values 7 different strategies - mean, median,fforward,backfoward
