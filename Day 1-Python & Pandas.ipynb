# %% [markdown]
# # Intro to Python

# %%
print('Hello World')
# Out:
# Hello World

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
print('Welcome'*1000)
# Out:
# ...

# %%
for i in range(1000):
    print('Welcome')
# Out:
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# Welcome
# ...

# %%
a=5
b=3
c=a*b
c
# Out:
# 15

# %%
list1=['Lisa','John','Paul',5,3,'My name is lisa']
for i in list1:
    print(i)
# Out:
# Lisa
# John
# Paul
# 5
# 3
# My name is lisa

# %%
list1
# Out:
# ['Lisa', 'John', 'Paul', 5, 3, 'My name is lisa']

# %%
#operator +(add) -(subtract) *(multiply) /(divide) 
# %(modulus: remainder in a division) **(squared)

# %%
#logic operators and, or, xor ==(true or false)
a==2
# Out:
# False

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is CCCC-39DA
#
#  Directory of C:\Users\gilbe\Downloads\Data Science BootCamp\Day 1
#
# 05/03/2023  12:05 AM    <DIR>          .
# 05/02/2023  11:14 PM    <DIR>          ..
# 05/02/2023  11:21 PM    <DIR>          .ipynb_checkpoints
# 05/02/2023  11:20 PM             6,681 catalog.xml
# 05/02/2023  11:20 PM               335 Courses.json
# 05/02/2023  11:20 PM               518 data.xml
# 05/03/2023  12:05 AM           519,394 Day 1-Python & Pandas.ipynb
# 05/02/2023  11:20 PM            11,658 excel-comp-data.xlsx
# 05/02/2023  11:45 PM               627 fortune 10.csv
# 05/02/2023  11:20 PM             5,552 sales-estimate.xlsx
# 05/02/2023  11:20 PM             5,680 sales-funnel.xlsx
# 05/02/2023  11:20 PM                40 test_pandas.csv
# 05/02/2023  11:20 PM            36,864 test_pandas.db
# 05/02/2023  11:20 PM            30,093 test_pandas.xlsm
# 05/02/2023  11:20 PM                43 test_pandas_no_header.csv
# ...

# %%
pwd
# Out:
# 'C:\\Users\\gilbe\\Downloads\\Data Science BootCamp\\Day 1'

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.max(), df.Age.min(),df.Age.mean()
# Out:
# (80.0, 0.42, 29.69911764705882)

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Fortune_Global_500')[0]

# %%
df
# Out:
#    Rank                               Company        Country  \
# 0     1                               Walmart  United States
# 1     2                                Amazon  United States
# 2     3                            State Grid          China
# 3     4              China National Petroleum          China
# 4     5                         Sinopec Group          China
# 5     6                          Saudi Aramco   Saudi Arabia
# 6     7                                 Apple  United States
# 7     8                            Volkswagen        Germany
# 8     9  China State Construction Engineering          China
# 9    10                            CVS Health  United States
#
#                           Industry  Revenue in USD
# 0                           Retail  $572.8 billion
# 1  Internet Services and Retailing  $469.8 billion
# 2                           Energy  $460.6 billion
# 3                        Petroleum  $411.7 billion
# ...

# %%
df=pd.read_html('https://travel.state.gov/content/travel/en/traveladvisories/traveladvisories.html/')[0]
df.head()
# Out:
#                           Advisory                                 Level  \
# 0    Liechtenstein Travel Advisory  Level 1: Exercise Normal Precautions
# 1  North Macedonia Travel Advisory  Level 1: Exercise Normal Precautions
# 2            Nauru Travel Advisory  Level 1: Exercise Normal Precautions
# 3            Palau Travel Advisory  Level 1: Exercise Normal Precautions
# 4  Burma (Myanmar) Travel Advisory                Level 4: Do Not Travel
#
#         Date Updated
# 0    October 4, 2022
# 1    October 4, 2022
# 2    October 5, 2022
# 3   January 19, 2023
# 4  February 27, 2023

# %%
df.to_csv('fortune 10.csv')

# %%
df=pd.read_xml('catalog.xml')

# %%
df.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
df=pd.read_clipboard()

# %%
df
# Out:
# Empty DataFrame
# Columns: [sns.pairplot(df)]
# Index: []

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Survived')

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# EDA-Exploratory Data Analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts(normalize=True)
# Out:
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: Embarked, dtype: float64

# %%
sns.countplot(x=df['Embarked'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
df.hist();

# %%
# pip install gtts

# %%
from gtts import gTTS
text='Python is a good programming Language, I love AI'
output=gTTS(text=text, lang='tr',slow=False)
output.save('recording.mp3')

# %%
from IPython.display import Audio
audio=Audio('recording.mp3')
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text='Qiero Comerlo'
output=gTTS(text=text, lang='es',slow=False)
output.save('Spanish.mp3')

# %%
from IPython.display import Audio
audio=Audio('Spanish.mp3')
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
